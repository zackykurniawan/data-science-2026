# %% [markdown]
# # Pertemuan 1 — Pengenalan Data Science
#
# **Nama Lengkap** : Muhammad Zacky Kurniawan
# **NIM** : 240401010217
# **Kelas** : IF403

# %% [markdown]
# <a href="https://colab.research.google.com/github/zackykurniawan/data-science-2026/blob/main/Pertemuan1_MuhammadZackyKurniawan_240401010217.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel dan tipe data dasar
nama      = "Muhammad Zacky Kurniawan"  # String
angkatan  = 2024                       # Integer
ipk       = 4                          # Float
aktif     = True                       # Boolean

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")

# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")

# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Muhammad Zacky Kurniawan", "Informatika", 2024)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama     : Muhammad Zacky Kurniawan
# Angkatan : 2024
# IPK      : 4
# Aktif    : True
#
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub
# Hai! Saya Muhammad Zacky Kurniawan dari Informatika, angkatan 2024.

# %% [markdown]
# ## Kesimpulan
#
# ### Apa yang Dipelajari
# Pada pertemuan pertama ini, saya mempelajari dasar-dasar pemrograman Python dalam konteks Data Science, meliputi: output sederhana menggunakan `print()`, penggunaan variabel dengan berbagai tipe data (String, Integer, Float, Boolean), iterasi menggunakan list dan perulangan `for`, serta pembuatan dan pemanggilan fungsi sederhana. Selain itu, saya juga mengenal ekosistem tools Data Science seperti Google Colab, Jupyter Notebook, dan GitHub.
#
# ### Temuan Utama
# - Python memiliki sintaksis yang bersih dan mudah dipahami, sehingga cocok sebagai bahasa pertama dalam belajar Data Science.
# - *f-string* (`f"...{variabel}..."`) adalah cara yang praktis dan mudah dibaca untuk memformat output.
# - Fungsi membantu membuat kode lebih terstruktur dan dapat digunakan kembali (*reusable*).
# - Google Colab memungkinkan kita menjalankan kode Python langsung di browser tanpa instalasi apapun.
#
# ### Keterbatasan & Pertanyaan yang Muncul
# - Bagaimana cara terbaik mengorganisasi banyak sel dalam satu notebook agar tetap rapi dan mudah dibaca?
